# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
from torchvision.datasets import DatasetFolder
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ## Training CNN on EEG spectrum data

# %%
class EEGDataset(Dataset):
    def __init__(self, csv_file, transform=None):

        self.data = pd.read_csv(csv_file)
        self.diagnosis_map ={'MDD': 1.0, 'Health': 0.0, 'Health-2': 0.0}
        self.transform =transform

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):

        raw = self.data.iloc[idx]
        eeg =np.load(raw['file'])
        if eeg.shape[0]==15:
            eeg =np.delete(eeg, 7, 0)
        label =self.diagnosis_map[raw['diagnosis']]
      
        if self.transform:
            eeg = self.transform(eeg)

        return eeg, label

# %%
train_dataset =EEGDataset('spectrums_short/train2.csv')
val_dataset =EEGDataset('spectrums_short/val2.csv')

# %%
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, drop_last = False)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, drop_last = True)

# %%
class EEGCNN(nn.Module):
    def __init__(self):
        super(EEGCNN, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.Conv2d(14, 14, (3,3), stride=1, padding=1),
            nn.BatchNorm2d(14),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))
            
        self.cnn2 = nn.Sequential(
            nn.Conv2d(14, 8, (3,3), stride=1, padding=1),
            nn.BatchNorm2d(8),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))

        
        self.pool = nn.AdaptiveAvgPool2d((3,9))
        self.fc = nn.Sequential(nn.Linear(8*3*9, 2))


    def forward(self, x):
        x = self.cnn1(x)
        x = self.cnn2(x)
        x=self.pool(x)
        classes =self.fc(x.view(-1, 8*3*9))
        
        return classes

# %%
class EEGCNNv2(nn.Module):
    def __init__(self):
        super(EEGCNN, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.Conv2d(15, 15, (23,1), stride=1, padding=1, groups=15),
            nn.BatchNorm2d(15),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))
            
        self.cnn2 = nn.Sequential(
            nn.Conv2d(15, 15, (1,1), stride=1, padding=1),
            nn.BatchNorm2d(15),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))

        
        self.pool = nn.AdaptiveAvgPool2d((1,6))
        self.fc = nn.Sequential(nn.Linear(15*1*6, 2))


    def forward(self, x):
        x = self.cnn1(x)
        x = self.cnn2(x)
        x=self.pool(x)
        classes =self.fc(x.view(-1, *1*6))
        
        return classes

# %%
28/4
# Out:
# 7.0

# %% [markdown]
# learning_rate =0.001
# num_epochs =800

# %%
learning_rate =0.00001
num_epochs =300

# %%
## 0.001 -the best

# %%
model = EEGCNN().cuda()

# %%
model
# Out:
# EEGCNN(
#   (cnn1): Sequential(
#     (0): Conv2d(14, 14, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn2): Sequential(
#     (0): Conv2d(14, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(3, 9))
#   (fc): Sequential(
#     (0): Linear(in_features=216, out_features=2, bias=True)
#   )
# )

# %%
model = EEGCNN().cuda()
criterion = nn.MSELoss()
cr_loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                             weight_decay=1e-1)

# %%
batch, labels =next(iter(train_loader))

# %%
batch =batch.float().cuda()

# %%
batch.shape
# Out:
# torch.Size([4, 14, 24, 98])

# %%
def plot_batch_and_outputs(batch, outputs, show_type ='img'):
    Y_ticks =np.linspace(0, 128, num=224)
    X_ticks =np.linspace(0, 45, num=24)
    random_channel =np.random.randint(batch.shape[1])
    levels =45
    
    if show_type =='img':
        print('True: ')
        spectrum = plt.imshow(batch[0,random_channel,:,:].detach().cpu().numpy(),cmap='jet')
        plt.show()
        print('Predicted: ')
        spectrum = plt.imshow(outputs[0,random_channel,:,:].detach().cpu().numpy(), cmap='jet')
        plt.show()
    else:
        spectrum = plt.contourf(Y_ticks,X_ticks,batch[0,random_channel,:,:].detach().cpu().numpy(),levels, cmap='jet')
        plt.show()
        print('Predicted: ')
        spectrum = plt.contourf(Y_ticks,X_ticks,outputs[0,random_channel,:,:].detach().cpu().numpy(),levels, cmap='jet')
        plt.show()

# %%
pred =model(batch)

# %%
pred.shape
# Out:
# torch.Size([4, 2])

# %%
#plot_batch_and_outputs(batch, output,show_type ='c')

# %%
batch.shape
# Out:
# torch.Size([4, 14, 24, 98])

# %%
writer = SummaryWriter('runs/cnn-novossib2')

# %%
for epoch in range(num_epochs):
    train_loss = 0
    train_correct =0
    train_total =0
    for data in train_loader:
        img, label = data
        img = img.float().cuda()
        label=label.long().cuda()
        # ===================forward=====================
        preds = model(img)
        _, predicted = torch.max(preds.data, 1)
        train_correct += (predicted == label).sum().item()
        train_total+= labels.size(0)
        
        loss =cr_loss(preds,label)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.data
    # ===================log========================
    if epoch % 1 == 0:
        with torch.no_grad():
            val_loss =0
            val_correct =0
            val_total =0
            for data in val_loader: 
                img, label = data
                img = img.float().cuda()
                label=label.long().cuda()
                preds  = model(img)
                _, predicted = torch.max(preds.data, 1)
                val_correct += (predicted == label).sum().item()
                val_total+= labels.size(0)
                loss =cr_loss(preds,label)
                val_loss += loss.data
            print(train_total)
            print(val_total)
            writer.add_scalar('training loss',
                            train_loss/train_total,
                            epoch)
            writer.add_scalar('validation loss',
                            val_loss/val_total,
                            epoch)
            writer.add_scalar('train accuracy',
                            train_correct/ train_total,
                            epoch)
            writer.add_scalar('val accuracy',
                            val_correct/ val_total,
                            epoch)
            print('epoch [{}/{}], train loss:{:.4f}'.format(epoch+1, num_epochs, train_loss/train_total))    
            print('epoch [{}/{}], val loss:{:.4f}'.format(epoch+1, num_epochs,val_loss/ val_total))
            print('epoch [{}/{}], train accuracy:{:.4f}'.format(epoch+1, num_epochs, train_correct/ train_total)) 
            print('epoch [{}/{}], val accuracy:{:.4f}'.format(epoch+1, num_epochs, val_correct/ val_total)) 
            #plot_batch_and_outputs(img, output,show_type ='c')
# Out:
# 1524
# 484
# epoch [1/300], train loss:0.1662
# epoch [1/300], val loss:0.1760
# epoch [1/300], train accuracy:0.5761
# epoch [1/300], val accuracy:0.3616
# 1524
# 484
# epoch [2/300], train loss:0.1623
# epoch [2/300], val loss:0.1821
# epoch [2/300], train accuracy:0.6004
# epoch [2/300], val accuracy:0.3161
# 1524
# 484
# epoch [3/300], train loss:0.1601
# epoch [3/300], val loss:0.1846
# epoch [3/300], train accuracy:0.6280
# epoch [3/300], val accuracy:0.2955
# 1524
# 484
# epoch [4/300], train loss:0.1578
# epoch [4/300], val loss:0.1865
# epoch [4/300], train accuracy:0.6299
# epoch [4/300], val accuracy:0.2893
# 1524
# 484
# epoch [5/300], train loss:0.1559
# epoch [5/300], val loss:0.1896
# epoch [5/300], train accuracy:0.6522
# epoch [5/300], val accuracy:0.2975
# 1524
# 484
# epoch [6/300], train loss:0.1527
# epoch [6/300], val loss:0.1886
# epoch [6/300], train accuracy:0.6759
# epoch [6/300], val accuracy:0.3182
# 1524
# 484
# epoch [7/300], train loss:0.1505
# epoch [7/300], val loss:0.1913
# epoch [7/300], train accuracy:0.6962
# epoch [7/300], val accuracy:0.3182
# 1524
# 484
# epoch [8/300], train loss:0.1486
# epoch [8/300], val loss:0.1964
# epoch [8/300], train accuracy:0.6791
# epoch [8/300], val accuracy:0.3037
# 1524
# 484
# epoch [9/300], train loss:0.1471
# epoch [9/300], val loss:0.1974
# epoch [9/300], train accuracy:0.6942
# epoch [9/300], val accuracy:0.3099
# 1524
# 484
# epoch [10/300], train loss:0.1430
# epoch [10/300], val loss:0.1939
# epoch [10/300], train accuracy:0.7178
# epoch [10/300], val accuracy:0.3574
# 1524
# 484
# epoch [11/300], train loss:0.1422
# epoch [11/300], val loss:0.2030
# epoch [11/300], train accuracy:0.7244
# epoch [11/300], val accuracy:0.3306
# 1524
# 484
# epoch [12/300], train loss:0.1403
# epoch [12/300], val loss:0.2067
# epoch [12/300], train accuracy:0.7192
# epoch [12/300], val accuracy:0.3368
# 1524
# 484
# epoch [13/300], train loss:0.1369
# epoch [13/300], val loss:0.2098
# epoch [13/300], train accuracy:0.7546
# epoch [13/300], val accuracy:0.3368
# 1524
# 484
# epoch [14/300], train loss:0.1363
# epoch [14/300], val loss:0.2106
# epoch [14/300], train accuracy:0.7349
# epoch [14/300], val accuracy:0.3430
# 1524
# 484
# epoch [15/300], train loss:0.1331
# epoch [15/300], val loss:0.2038
# epoch [15/300], train accuracy:0.7520
# epoch [15/300], val accuracy:0.3822
# 1524
# 484
# epoch [16/300], train loss:0.1321
# epoch [16/300], val loss:0.2125
# epoch [16/300], train accuracy:0.7684
# epoch [16/300], val accuracy:0.3740
# 1524
# 484
# epoch [17/300], train loss:0.1294
# epoch [17/300], val loss:0.2198
# epoch [17/300], train accuracy:0.7762
# epoch [17/300], val accuracy:0.3657
# 1524
# 484
# epoch [18/300], train loss:0.1270
# epoch [18/300], val loss:0.2160
# epoch [18/300], train accuracy:0.7867
# epoch [18/300], val accuracy:0.3988
# 1524
# 484
# epoch [19/300], train loss:0.1257
# epoch [19/300], val loss:0.2218
# epoch [19/300], train accuracy:0.7815
# epoch [19/300], val accuracy:0.3884
# 1524
# 484
# epoch [20/300], train loss:0.1221
# epoch [20/300], val loss:0.2226
# epoch [20/300], train accuracy:0.8012
# epoch [20/300], val accuracy:0.4029
# 1524
# 484
# epoch [21/300], train loss:0.1232
# epoch [21/300], val loss:0.2275
# epoch [21/300], train accuracy:0.7966
# epoch [21/300], val accuracy:0.4008
# 1524
# 484
# epoch [22/300], train loss:0.1186
# epoch [22/300], val loss:0.2323
# epoch [22/300], train accuracy:0.8038
# epoch [41/300], val loss:0.2769
# epoch [41/300], train accuracy:0.8465
# epoch [41/300], val accuracy:0.4298
# 1524
# 484
# epoch [42/300], train loss:0.0978
# epoch [42/300], val loss:0.2852
# epoch [42/300], train accuracy:0.8386
# epoch [42/300], val accuracy:0.4215
# 1524
# 484
# epoch [43/300], train loss:0.0969
# epoch [43/300], val loss:0.2938
# epoch [43/300], train accuracy:0.8504
# epoch [43/300], val accuracy:0.4112
# 1524
# 484
# epoch [44/300], train loss:0.0977
# epoch [44/300], val loss:0.2884
# epoch [44/300], train accuracy:0.8294
# epoch [44/300], val accuracy:0.4194
# 1524
# 484
# epoch [45/300], train loss:0.0967
# epoch [45/300], val loss:0.2840
# epoch [45/300], train accuracy:0.8392
# epoch [45/300], val accuracy:0.4298
# 1524
# 484
# epoch [46/300], train loss:0.0954
# epoch [46/300], val loss:0.2749
# epoch [46/300], train accuracy:0.8425
# epoch [46/300], val accuracy:0.4483
# 1524
# 484
# epoch [47/300], train loss:0.0950
# epoch [47/300], val loss:0.2718
# epoch [47/300], train accuracy:0.8438
# epoch [47/300], val accuracy:0.4545
# 1524
# 484
# epoch [48/300], train loss:0.0931
# epoch [48/300], val loss:0.2782
# epoch [48/300], train accuracy:0.8530
# epoch [48/300], val accuracy:0.4421
# 1524
# 484
# epoch [49/300], train loss:0.0922
# epoch [49/300], val loss:0.2925
# epoch [49/300], train accuracy:0.8615
# epoch [49/300], val accuracy:0.4215
# 1524
# 484
# epoch [50/300], train loss:0.0896
# epoch [50/300], val loss:0.2929
# epoch [50/300], train accuracy:0.8524
# epoch [50/300], val accuracy:0.4215
# 1524
# 484
# epoch [51/300], train loss:0.0913
# epoch [51/300], val loss:0.2852
# epoch [51/300], train accuracy:0.8524
# epoch [51/300], val accuracy:0.4401
# 1524
# 484
# epoch [52/300], train loss:0.0914
# epoch [52/300], val loss:0.3087
# epoch [52/300], train accuracy:0.8484
# epoch [52/300], val accuracy:0.3988
# 1524
# 484
# epoch [53/300], train loss:0.0902
# epoch [53/300], val loss:0.3237
# epoch [53/300], train accuracy:0.8576
# epoch [53/300], val accuracy:0.3884
# 1524
# 484
# epoch [54/300], train loss:0.0884
# epoch [54/300], val loss:0.2845
# epoch [54/300], train accuracy:0.8556
# epoch [54/300], val accuracy:0.4525
# 1524
# 484
# epoch [55/300], train loss:0.0862
# epoch [55/300], val loss:0.3172
# epoch [55/300], train accuracy:0.8589
# epoch [55/300], val accuracy:0.3946
# 1524
# 484
# epoch [56/300], train loss:0.0873
# epoch [56/300], val loss:0.3087
# epoch [56/300], train accuracy:0.8563
# epoch [56/300], val accuracy:0.4070
# 1524
# 484
# epoch [57/300], train loss:0.0890
# epoch [57/300], val loss:0.2901
# epoch [57/300], train accuracy:0.8451
# epoch [57/300], val accuracy:0.4463
# 1524
# 484
# epoch [58/300], train loss:0.0873
# epoch [58/300], val loss:0.3064
# epoch [58/300], train accuracy:0.8537
# epoch [58/300], val accuracy:0.4070
# 1524
# 484
# epoch [59/300], train loss:0.0873
# epoch [59/300], val loss:0.3110
# epoch [59/300], train accuracy:0.8596
# epoch [245/300], val loss:0.2390
# epoch [245/300], train accuracy:0.9213
# epoch [245/300], val accuracy:0.4979
# 1524
# 484
# epoch [246/300], train loss:0.0595
# epoch [246/300], val loss:0.2303
# epoch [246/300], train accuracy:0.9206
# epoch [246/300], val accuracy:0.5145
# 1524
# 484
# epoch [247/300], train loss:0.0591
# epoch [247/300], val loss:0.2550
# epoch [247/300], train accuracy:0.9068
# epoch [247/300], val accuracy:0.4690
# 1524
# 484
# epoch [248/300], train loss:0.0590
# epoch [248/300], val loss:0.2486
# epoch [248/300], train accuracy:0.9206
# epoch [248/300], val accuracy:0.4773
# 1524
# 484
# epoch [249/300], train loss:0.0581
# epoch [249/300], val loss:0.2124
# epoch [249/300], train accuracy:0.9206
# epoch [249/300], val accuracy:0.5372
# 1524
# 484
# epoch [250/300], train loss:0.0577
# epoch [250/300], val loss:0.2359
# epoch [250/300], train accuracy:0.9265
# epoch [250/300], val accuracy:0.5000
# 1524
# 484
# epoch [251/300], train loss:0.0573
# epoch [251/300], val loss:0.2310
# epoch [251/300], train accuracy:0.9160
# epoch [251/300], val accuracy:0.5124
# 1524
# 484
# epoch [252/300], train loss:0.0601
# epoch [252/300], val loss:0.2329
# epoch [252/300], train accuracy:0.9154
# epoch [252/300], val accuracy:0.5124
# 1524
# 484
# epoch [253/300], train loss:0.0597
# epoch [253/300], val loss:0.2695
# epoch [253/300], train accuracy:0.9154
# epoch [253/300], val accuracy:0.4545
# 1524
# 484
# epoch [254/300], train loss:0.0588
# epoch [254/300], val loss:0.2284
# epoch [254/300], train accuracy:0.9147
# epoch [254/300], val accuracy:0.5165
# 1524
# 484
# epoch [255/300], train loss:0.0580
# epoch [255/300], val loss:0.2495
# epoch [255/300], train accuracy:0.9259
# epoch [255/300], val accuracy:0.4752
# 1524
# 484
# epoch [256/300], train loss:0.0571
# epoch [256/300], val loss:0.2366
# epoch [256/300], train accuracy:0.9199
# epoch [256/300], val accuracy:0.4979
# 1524
# 484
# epoch [257/300], train loss:0.0565
# epoch [257/300], val loss:0.2359
# epoch [257/300], train accuracy:0.9232
# epoch [257/300], val accuracy:0.4959
# 1524
# 484
# epoch [258/300], train loss:0.0572
# epoch [258/300], val loss:0.2399
# epoch [258/300], train accuracy:0.9173
# epoch [258/300], val accuracy:0.5021
# 1524
# 484
# epoch [259/300], train loss:0.0587
# epoch [259/300], val loss:0.2493
# epoch [259/300], train accuracy:0.9213
# epoch [259/300], val accuracy:0.4773
# 1524
# 484
# epoch [260/300], train loss:0.0574
# epoch [260/300], val loss:0.2300
# epoch [260/300], train accuracy:0.9245
# epoch [260/300], val accuracy:0.5145
# 1524
# 484
# epoch [261/300], train loss:0.0569
# epoch [261/300], val loss:0.2598
# epoch [261/300], train accuracy:0.9239
# epoch [261/300], val accuracy:0.4607
# 1524
# 484
# epoch [262/300], train loss:0.0600
# epoch [262/300], val loss:0.2540
# epoch [262/300], train accuracy:0.9245
# epoch [262/300], val accuracy:0.4731
# 1524
# 484
# epoch [263/300], train loss:0.0586
# epoch [263/300], val loss:0.2551
# epoch [263/300], train accuracy:0.9167
# epoch [263/300], val accuracy:0.4669
# 1524
# 484
# epoch [264/300], train loss:0.0572
# epoch [264/300], val loss:0.2853
# epoch [264/300], train accuracy:0.9239
# epoch [264/300], val accuracy:0.4442
# 1524
# 484
# epoch [265/300], train loss:0.0590
# epoch [265/300], val loss:0.2247
# epoch [265/300], train accuracy:0.9167
# epoch [265/300], val accuracy:0.5186
# 1524
# 484
# epoch [266/300], train loss:0.0587
# epoch [266/300], val loss:0.2236
# epoch [266/300], train accuracy:0.9140
# epoch [266/300], val accuracy:0.5145
# 1524
# 484
# epoch [267/300], train loss:0.0587
# epoch [267/300], val loss:0.2153
# epoch [267/300], train accuracy:0.9186
# epoch [267/300], val accuracy:0.5289
# 1524
# 484
# epoch [268/300], train loss:0.0580
# epoch [268/300], val loss:0.2349
# epoch [268/300], train accuracy:0.9213
# epoch [268/300], val accuracy:0.4938
# 1524
# 484
# epoch [269/300], train loss:0.0558
# epoch [269/300], val loss:0.2209
# epoch [269/300], train accuracy:0.9213
# epoch [269/300], val accuracy:0.5186
# 1524
# 484
# epoch [270/300], train loss:0.0589
# epoch [270/300], val loss:0.2441
# epoch [270/300], train accuracy:0.9199
# epoch [270/300], val accuracy:0.4793
# 1524
# 484
# epoch [271/300], train loss:0.0587
# epoch [271/300], val loss:0.2410
# epoch [271/300], train accuracy:0.9121
# epoch [271/300], val accuracy:0.4897
# 1524
# 484
# epoch [272/300], train loss:0.0560
# epoch [272/300], val loss:0.2088
# epoch [272/300], train accuracy:0.9245
# epoch [272/300], val accuracy:0.5455
# 1524
# 484
# epoch [273/300], train loss:0.0585
# epoch [273/300], val loss:0.2767
# epoch [273/300], train accuracy:0.9173
# epoch [273/300], val accuracy:0.4504
# 1524
# 484
# epoch [274/300], train loss:0.0562
# epoch [274/300], val loss:0.2414
# epoch [274/300], train accuracy:0.9213
# epoch [274/300], val accuracy:0.4855
# 1524
# 484
# epoch [275/300], train loss:0.0564
# epoch [275/300], val loss:0.2252
# epoch [275/300], train accuracy:0.9259
# epoch [275/300], val accuracy:0.5124
# 1524
# 484
# epoch [276/300], train loss:0.0560
# epoch [276/300], val loss:0.2537
# epoch [276/300], train accuracy:0.9193
# epoch [276/300], val accuracy:0.4731
# 1524
# 484
# epoch [277/300], train loss:0.0560
# epoch [277/300], val loss:0.2417
# epoch [277/300], train accuracy:0.9180
# epoch [277/300], val accuracy:0.4876
# 1524
# 484
# epoch [278/300], train loss:0.0560
# epoch [278/300], val loss:0.2347
# epoch [278/300], train accuracy:0.9259
# epoch [278/300], val accuracy:0.4979
# 1524
# 484
# epoch [279/300], train loss:0.0589
# epoch [279/300], val loss:0.2629
# epoch [279/300], train accuracy:0.9173
# epoch [279/300], val accuracy:0.4669
# 1524
# 484
# epoch [280/300], train loss:0.0547
# epoch [280/300], val loss:0.2490
# epoch [280/300], train accuracy:0.9291
# epoch [280/300], val accuracy:0.4752
# 1524
# 484
# epoch [281/300], train loss:0.0570
# epoch [281/300], val loss:0.2975
# epoch [281/300], train accuracy:0.9180
# epoch [281/300], val accuracy:0.4360
# 1524
# 484
# epoch [282/300], train loss:0.0574
# epoch [282/300], val loss:0.2883
# epoch [282/300], train accuracy:0.9245
# epoch [282/300], val accuracy:0.4401
# 1524
# 484
# epoch [283/300], train loss:0.0580
# epoch [283/300], val loss:0.2478
# epoch [283/300], train accuracy:0.9199
# epoch [283/300], val accuracy:0.4773
# 1524
# 484
# epoch [284/300], train loss:0.0594
# epoch [284/300], val loss:0.2284
# epoch [284/300], train accuracy:0.9193
# epoch [284/300], val accuracy:0.5103
# 1524
# 484
# epoch [285/300], train loss:0.0556
# epoch [285/300], val loss:0.2038
# epoch [285/300], train accuracy:0.9311
# epoch [285/300], val accuracy:0.5475
# 1524
# 484
# epoch [286/300], train loss:0.0585
# epoch [286/300], val loss:0.2443
# epoch [286/300], train accuracy:0.9193
# epoch [286/300], val accuracy:0.4773
# 1524
# 484
# epoch [287/300], train loss:0.0564
# epoch [287/300], val loss:0.2083
# epoch [287/300], train accuracy:0.9318
# epoch [287/300], val accuracy:0.5413
# 1524
# 484
# epoch [288/300], train loss:0.0557
# epoch [288/300], val loss:0.2110
# epoch [288/300], train accuracy:0.9291
# epoch [288/300], val accuracy:0.5455
# 1524
# 484
# epoch [289/300], train loss:0.0562
# epoch [289/300], val loss:0.2227
# epoch [289/300], train accuracy:0.9278
# epoch [289/300], val accuracy:0.5186
# 1524
# 484
# epoch [290/300], train loss:0.0575
# epoch [290/300], val loss:0.2633
# epoch [290/300], train accuracy:0.9239
# epoch [290/300], val accuracy:0.4628
# 1524
# 484
# epoch [291/300], train loss:0.0591
# epoch [291/300], val loss:0.2416
# epoch [291/300], train accuracy:0.9252
# epoch [291/300], val accuracy:0.4814
# 1524
# 484
# epoch [292/300], train loss:0.0571
# epoch [292/300], val loss:0.2401
# epoch [292/300], train accuracy:0.9331
# epoch [292/300], val accuracy:0.4876
# 1524
# 484
# epoch [293/300], train loss:0.0560
# epoch [293/300], val loss:0.2213
# epoch [293/300], train accuracy:0.9239
# epoch [293/300], val accuracy:0.5207
# 1524
# 484
# epoch [294/300], train loss:0.0572
# epoch [294/300], val loss:0.2234
# epoch [294/300], train accuracy:0.9311
# epoch [294/300], val accuracy:0.5248
# 1524
# 484
# epoch [295/300], train loss:0.0567
# epoch [295/300], val loss:0.2524
# epoch [295/300], train accuracy:0.9226
# epoch [295/300], val accuracy:0.4711
# 1524
# 484
# epoch [296/300], train loss:0.0569
# epoch [296/300], val loss:0.2253
# epoch [296/300], train accuracy:0.9304
# epoch [296/300], val accuracy:0.5165
# 1524
# 484
# epoch [297/300], train loss:0.0552
# epoch [297/300], val loss:0.2466
# epoch [297/300], train accuracy:0.9324
# epoch [297/300], val accuracy:0.4793
# 1524
# 484
# epoch [298/300], train loss:0.0558
# epoch [298/300], val loss:0.2309
# epoch [298/300], train accuracy:0.9259
# epoch [298/300], val accuracy:0.5145
# 1524
# 484
# epoch [299/300], train loss:0.0569
# epoch [299/300], val loss:0.2340
# epoch [299/300], train accuracy:0.9278
# epoch [299/300], val accuracy:0.5041
# 1524
# 484
# epoch [300/300], train loss:0.0567
# epoch [300/300], val loss:0.2261
# epoch [300/300], train accuracy:0.9193
# epoch [300/300], val accuracy:0.5145
