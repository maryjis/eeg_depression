# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
from torchvision.datasets import DatasetFolder
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ## Training CNN on EEG spectrum data

# %%
class EEGDataset(Dataset):
    def __init__(self, csv_file, transform=None):

        self.data = pd.read_csv(csv_file)
        self.diagnosis_map ={'MDD': 1.0, 'Health': 0.0, 'Health-2': 0.0}
        self.transform =transform

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):

        raw = self.data.iloc[idx]
        eeg =np.load(raw['file'])
        if eeg.shape[0]==15:
            eeg =np.delete(eeg, 7, 0)
        label =self.diagnosis_map[raw['diagnosis']]
      
        if self.transform:
            eeg = self.transform(eeg)

        return eeg, label

# %%
train_dataset =EEGDataset('cross_spectrum_short/train.csv')
val_dataset =EEGDataset('cross_spectrum_short/val.csv')

# %%
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, drop_last = False)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, drop_last = True)

# %%
class EEGCNN(nn.Module):
    def __init__(self):
        super(EEGCNN, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.Conv2d(4, 16, (3,3), stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))
            
        self.cnn2 = nn.Sequential(
            nn.Conv2d(16, 8, (3,3), stride=1, padding=1),
            nn.BatchNorm2d(8),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))

        
        self.pool = nn.AdaptiveAvgPool2d((3,3))
        self.fc = nn.Sequential(nn.Linear(8*3*3, 2))


    def forward(self, x):
        x = self.cnn1(x)
        x = self.cnn2(x)
        x=self.pool(x)
        classes =self.fc(x.view(-1, 8*3*3))
        
        return classes

# %%
class EEGCNNv2(nn.Module):
    def __init__(self):
        super(EEGCNN, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.Conv2d(15, 15, (23,1), stride=1, padding=1, groups=15),
            nn.BatchNorm2d(15),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))
            
        self.cnn2 = nn.Sequential(
            nn.Conv2d(15, 15, (1,1), stride=1, padding=1),
            nn.BatchNorm2d(15),
            nn.ELU(True),
            nn.MaxPool2d(2, stride=2))

        
        self.pool = nn.AdaptiveAvgPool2d((1,6))
        self.fc = nn.Sequential(nn.Linear(15*1*6, 2))


    def forward(self, x):
        x = self.cnn1(x)
        x = self.cnn2(x)
        x=self.pool(x)
        classes =self.fc(x.view(-1, *1*6))
        
        return classes

# %%
28/4
# Out:
# 7.0

# %% [markdown]
# learning_rate =0.001
# num_epochs =800

# %%
learning_rate =0.0001
num_epochs =300

# %%
## 0.001 -the best

# %%
model = EEGCNN().cuda()

# %%
model
# Out:
# EEGCNN(
#   (cnn1): Sequential(
#     (0): Conv2d(4, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn2): Sequential(
#     (0): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(3, 3))
#   (fc): Sequential(
#     (0): Linear(in_features=72, out_features=2, bias=True)
#   )
# )

# %%
model = EEGCNN().cuda()
criterion = nn.MSELoss()
cr_loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                             weight_decay=1e-1)

# %%
batch, labels =next(iter(train_loader))

# %%
batch =batch.float().cuda()

# %%
batch.shape
# Out:
# torch.Size([4, 4, 15, 15])

# %%
def plot_batch_and_outputs(batch, outputs, show_type ='img'):
    Y_ticks =np.linspace(0, 15, num=15)
    X_ticks =np.linspace(0, 15, num=15)
    random_channel =np.random.randint(batch.shape[1])
    levels =45
    
    if show_type =='img':
        print('True: ')
        spectrum = plt.imshow(batch[0,random_channel,:,:].detach().cpu().numpy(),cmap='jet')
        plt.show()
        print('Predicted: ')
        spectrum = plt.imshow(outputs[0,random_channel,:,:].detach().cpu().numpy(), cmap='jet')
        plt.show()
    else:
        spectrum = plt.contourf(Y_ticks,X_ticks,batch[0,random_channel,:,:].detach().cpu().numpy(),levels, cmap='jet')
        plt.show()
        print('Predicted: ')
        spectrum = plt.contourf(Y_ticks,X_ticks,outputs[0,random_channel,:,:].detach().cpu().numpy(),levels, cmap='jet')
        plt.show()

# %%
pred =model(batch)

# %%
pred.shape
# Out:
# torch.Size([4, 2])

# %%
#plot_batch_and_outputs(batch, output,show_type ='c')

# %%
batch.shape
# Out:
# torch.Size([4, 4, 15, 15])

# %%
writer = SummaryWriter('runs/cross-corr-cnn')

# %%
for epoch in range(num_epochs):
    train_loss = 0
    train_correct =0
    train_total =0
    for data in train_loader:
        img, label = data
        img = img.float().cuda()
        label=label.long().cuda()
        # ===================forward=====================
        preds = model(img)
        _, predicted = torch.max(preds.data, 1)
        train_correct += (predicted == label).sum().item()
        train_total+= labels.size(0)
        
        loss =cr_loss(preds,label)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.data
    # ===================log========================
    if epoch % 1 == 0:
        with torch.no_grad():
            val_loss =0
            val_correct =0
            val_total =0
            for data in val_loader: 
                img, label = data
                img = img.float().cuda()
                label=label.long().cuda()
                preds  = model(img)
                _, predicted = torch.max(preds.data, 1)
                val_correct += (predicted == label).sum().item()
                val_total+= labels.size(0)
                loss =cr_loss(preds,label)
                val_loss += loss.data
            print(train_total)
            print(val_total)
            writer.add_scalar('training loss',
                            train_loss/train_total,
                            epoch)
            writer.add_scalar('validation loss',
                            val_loss/val_total,
                            epoch)
            writer.add_scalar('train accuracy',
                            train_correct/ train_total,
                            epoch)
            writer.add_scalar('val accuracy',
                            val_correct/ val_total,
                            epoch)
            print('epoch [{}/{}], train loss:{:.4f}'.format(epoch+1, num_epochs, train_loss/train_total))    
            print('epoch [{}/{}], val loss:{:.4f}'.format(epoch+1, num_epochs,val_loss/ val_total))
            print('epoch [{}/{}], train accuracy:{:.4f}'.format(epoch+1, num_epochs, train_correct/ train_total)) 
            print('epoch [{}/{}], val accuracy:{:.4f}'.format(epoch+1, num_epochs, val_correct/ val_total)) 
            #plot_batch_and_outputs(img, output,show_type ='c')
# Out:
# 196
# 48
# epoch [1/300], train loss:0.1722
# epoch [1/300], val loss:0.1692
# epoch [1/300], train accuracy:0.6020
# epoch [1/300], val accuracy:0.6250
# 196
# 48
# epoch [2/300], train loss:0.1583
# epoch [2/300], val loss:0.1710
# epoch [2/300], train accuracy:0.6684
# epoch [2/300], val accuracy:0.5833
# 196
# 48
# epoch [3/300], train loss:0.1494
# epoch [3/300], val loss:0.1670
# epoch [3/300], train accuracy:0.6633
# epoch [3/300], val accuracy:0.5625
# 196
# 48
# epoch [4/300], train loss:0.1479
# epoch [4/300], val loss:0.1810
# epoch [4/300], train accuracy:0.6735
# epoch [4/300], val accuracy:0.5833
# 196
# 48
# epoch [5/300], train loss:0.1438
# epoch [5/300], val loss:0.1626
# epoch [5/300], train accuracy:0.7143
# epoch [5/300], val accuracy:0.5833
# 196
# 48
# epoch [6/300], train loss:0.1350
# epoch [6/300], val loss:0.1697
# epoch [6/300], train accuracy:0.7653
# epoch [6/300], val accuracy:0.5208
# 196
# 48
# epoch [7/300], train loss:0.1305
# epoch [7/300], val loss:0.1689
# epoch [7/300], train accuracy:0.7704
# epoch [7/300], val accuracy:0.5208
# 196
# 48
# epoch [8/300], train loss:0.1287
# epoch [8/300], val loss:0.1675
# epoch [8/300], train accuracy:0.7551
# epoch [8/300], val accuracy:0.5208
# 196
# 48
# epoch [9/300], train loss:0.1253
# epoch [9/300], val loss:0.1739
# epoch [9/300], train accuracy:0.7704
# epoch [9/300], val accuracy:0.5208
# 196
# 48
# epoch [10/300], train loss:0.1102
# epoch [10/300], val loss:0.1778
# epoch [10/300], train accuracy:0.8214
# epoch [10/300], val accuracy:0.6250
# 196
# 48
# epoch [11/300], train loss:0.1005
# epoch [11/300], val loss:0.2050
# epoch [11/300], train accuracy:0.8367
# epoch [11/300], val accuracy:0.5208
# 196
# 48
# epoch [12/300], train loss:0.1024
# epoch [12/300], val loss:0.1889
# epoch [12/300], train accuracy:0.8214
# epoch [12/300], val accuracy:0.4167
# 196
# 48
# epoch [13/300], train loss:0.1077
# epoch [13/300], val loss:0.1897
# epoch [13/300], train accuracy:0.8061
# epoch [13/300], val accuracy:0.4792
# 196
# 48
# epoch [14/300], train loss:0.0933
# epoch [14/300], val loss:0.2049
# epoch [14/300], train accuracy:0.8418
# epoch [14/300], val accuracy:0.5000
# 196
# 48
# epoch [15/300], train loss:0.0932
# epoch [15/300], val loss:0.2027
# epoch [15/300], train accuracy:0.8571
# epoch [15/300], val accuracy:0.3958
# 196
# 48
# epoch [16/300], train loss:0.0837
# epoch [16/300], val loss:0.2018
# epoch [16/300], train accuracy:0.9031
# epoch [16/300], val accuracy:0.4792
# 196
# 48
# epoch [17/300], train loss:0.0845
# epoch [17/300], val loss:0.2094
# epoch [17/300], train accuracy:0.8776
# epoch [17/300], val accuracy:0.4375
# 196
# 48
# epoch [18/300], train loss:0.0779
# epoch [18/300], val loss:0.2417
# epoch [18/300], train accuracy:0.8878
# epoch [18/300], val accuracy:0.5417
# 196
# 48
# epoch [19/300], train loss:0.0747
# epoch [19/300], val loss:0.2266
# epoch [19/300], train accuracy:0.9184
# epoch [19/300], val accuracy:0.4375
# 196
# 48
# epoch [20/300], train loss:0.0735
# epoch [20/300], val loss:0.2343
# epoch [20/300], train accuracy:0.9082
# epoch [20/300], val accuracy:0.4583
# 196
# 48
# epoch [21/300], train loss:0.0625
# epoch [21/300], val loss:0.2271
# epoch [21/300], train accuracy:0.9235
# epoch [21/300], val accuracy:0.4375
# 196
# 48
# epoch [22/300], train loss:0.0713
# epoch [22/300], val loss:0.2275
# epoch [22/300], train accuracy:0.8929
# epoch [22/300], val accuracy:0.3958
# 196
# 48
# epoch [23/300], train loss:0.0669
# epoch [23/300], val loss:0.2375
# epoch [23/300], train accuracy:0.9031
# epoch [23/300], val accuracy:0.4583
# 196
# 48
# epoch [24/300], train loss:0.0696
# epoch [24/300], val loss:0.2181
# epoch [24/300], train accuracy:0.8980
# epoch [24/300], val accuracy:0.3958
# 196
# 48
# epoch [25/300], train loss:0.0624
# epoch [25/300], val loss:0.2337
# epoch [25/300], train accuracy:0.9286
# epoch [25/300], val accuracy:0.4375
# 196
# 48
# epoch [26/300], train loss:0.0592
# epoch [26/300], val loss:0.2156
# epoch [26/300], train accuracy:0.9439
# epoch [26/300], val accuracy:0.5000
# 196
# 48
# epoch [27/300], train loss:0.0591
# epoch [27/300], val loss:0.2294
# epoch [27/300], train accuracy:0.9235
# epoch [27/300], val accuracy:0.4792
# 196
# 48
# epoch [28/300], train loss:0.0648
# epoch [28/300], val loss:0.2298
# epoch [28/300], train accuracy:0.9337
# epoch [28/300], val accuracy:0.5000
# 196
# 48
# epoch [29/300], train loss:0.0528
# epoch [29/300], val loss:0.2326
# epoch [29/300], train accuracy:0.9490
# epoch [29/300], val accuracy:0.5000
# 196
# 48
# epoch [30/300], train loss:0.0483
# epoch [30/300], val loss:0.2167
# epoch [30/300], train accuracy:0.9541
# epoch [30/300], val accuracy:0.5625
# 196
# 48
# epoch [31/300], train loss:0.0473
# epoch [31/300], val loss:0.2140
# epoch [31/300], train accuracy:0.9541
# epoch [31/300], val accuracy:0.5417
# 196
# 48
# epoch [32/300], train loss:0.0595
# epoch [32/300], val loss:0.2051
# epoch [32/300], train accuracy:0.9235
# epoch [32/300], val accuracy:0.5625
# 196
# 48
# epoch [33/300], train loss:0.0522
# epoch [33/300], val loss:0.2193
# epoch [33/300], train accuracy:0.9337
# epoch [33/300], val accuracy:0.5208
# 196
# 48
# epoch [34/300], train loss:0.0476
# epoch [34/300], val loss:0.2343
# epoch [34/300], train accuracy:0.9592
# epoch [34/300], val accuracy:0.5625
# 196
# 48
# epoch [35/300], train loss:0.0487
# epoch [35/300], val loss:0.2348
# epoch [35/300], train accuracy:0.9541
# epoch [35/300], val accuracy:0.5625
# 196
# 48
# epoch [36/300], train loss:0.0456
# epoch [36/300], val loss:0.2323
# epoch [36/300], train accuracy:0.9694
# epoch [36/300], val accuracy:0.6042
# 196
# 48
# epoch [37/300], train loss:0.0443
# epoch [37/300], val loss:0.2545
# epoch [37/300], train accuracy:0.9592
# epoch [37/300], val accuracy:0.6042
# 196
# 48
# epoch [38/300], train loss:0.0475
# epoch [38/300], val loss:0.2391
# epoch [38/300], train accuracy:0.9592
# epoch [38/300], val accuracy:0.5833
# 196
# 48
# epoch [39/300], train loss:0.0404
# epoch [39/300], val loss:0.2393
# epoch [39/300], train accuracy:0.9745
# epoch [39/300], val accuracy:0.5208
# 196
# 48
# epoch [40/300], train loss:0.0413
# epoch [40/300], val loss:0.2278
# epoch [40/300], train accuracy:0.9490
# epoch [40/300], val accuracy:0.6042
# 196
# 48
# epoch [41/300], train loss:0.0523
# epoch [41/300], val loss:0.2471
# epoch [41/300], train accuracy:0.9439
# epoch [41/300], val accuracy:0.5417
# 196
# 48
# epoch [42/300], train loss:0.0385
# epoch [42/300], val loss:0.2347
# epoch [42/300], train accuracy:0.9745
# epoch [42/300], val accuracy:0.4583
# 196
# 48
# epoch [43/300], train loss:0.0362
# epoch [43/300], val loss:0.2270
# epoch [43/300], train accuracy:0.9592
# epoch [43/300], val accuracy:0.5417
# 196
# 48
# epoch [44/300], train loss:0.0436
# epoch [44/300], val loss:0.2579
# epoch [44/300], train accuracy:0.9694
# epoch [44/300], val accuracy:0.5625
# 196
# 48
# epoch [45/300], train loss:0.0376
# epoch [45/300], val loss:0.2310
# epoch [45/300], train accuracy:0.9745
# epoch [45/300], val accuracy:0.6042
# 196
# 48
# epoch [46/300], train loss:0.0455
# epoch [46/300], val loss:0.2239
# epoch [46/300], train accuracy:0.9592
# epoch [46/300], val accuracy:0.5208
# 196
# 48
# epoch [47/300], train loss:0.0376
# epoch [47/300], val loss:0.2289
# epoch [47/300], train accuracy:0.9847
# epoch [47/300], val accuracy:0.5625
# 196
# 48
# epoch [48/300], train loss:0.0373
# epoch [48/300], val loss:0.2484
# epoch [48/300], train accuracy:0.9745
# epoch [48/300], val accuracy:0.4792
# 196
# 48
# epoch [49/300], train loss:0.0357
# epoch [49/300], val loss:0.2409
# epoch [49/300], train accuracy:0.9745
# epoch [49/300], val accuracy:0.5208
# 196
# 48
# epoch [50/300], train loss:0.0356
# epoch [50/300], val loss:0.2422
# epoch [50/300], train accuracy:0.9745
# epoch [50/300], val accuracy:0.4792
# 196
# 48
# epoch [51/300], train loss:0.0363
# epoch [51/300], val loss:0.2349
# epoch [51/300], train accuracy:0.9796
# epoch [51/300], val accuracy:0.4583
# 196
# 48
# epoch [52/300], train loss:0.0365
# epoch [52/300], val loss:0.2471
# epoch [52/300], train accuracy:0.9847
# epoch [52/300], val accuracy:0.5208
# 196
# 48
# epoch [53/300], train loss:0.0340
# epoch [53/300], val loss:0.2390
# epoch [53/300], train accuracy:0.9796
# epoch [53/300], val accuracy:0.5625
# 196
# 48
# epoch [54/300], train loss:0.0333
# epoch [54/300], val loss:0.2330
# epoch [54/300], train accuracy:0.9847
# epoch [54/300], val accuracy:0.5208
# 196
# 48
# epoch [55/300], train loss:0.0333
# epoch [55/300], val loss:0.2459
# epoch [55/300], train accuracy:0.9643
# epoch [55/300], val accuracy:0.5417
# 196
# 48
# epoch [56/300], train loss:0.0419
# epoch [56/300], val loss:0.2409
# epoch [56/300], train accuracy:0.9796
# epoch [56/300], val accuracy:0.5208
# 196
# 48
# epoch [57/300], train loss:0.0356
# epoch [57/300], val loss:0.2325
# epoch [57/300], train accuracy:0.9694
# epoch [57/300], val accuracy:0.4792
# 196
# 48
# epoch [58/300], train loss:0.0332
# epoch [58/300], val loss:0.2287
# epoch [58/300], train accuracy:0.9796
# epoch [58/300], val accuracy:0.5208
# 196
# 48
# epoch [59/300], train loss:0.0294
# epoch [59/300], val loss:0.2311
# epoch [59/300], train accuracy:0.9796
# epoch [59/300], val accuracy:0.5625
# epoch [78/300], train accuracy:0.9847
# epoch [78/300], val accuracy:0.5417
# 196
# 48
# epoch [79/300], train loss:0.0333
# epoch [79/300], val loss:0.2623
# epoch [79/300], train accuracy:0.9694
# epoch [79/300], val accuracy:0.4583
# 196
# 48
# epoch [80/300], train loss:0.0363
# epoch [80/300], val loss:0.2759
# epoch [80/300], train accuracy:0.9694
# epoch [80/300], val accuracy:0.4167
# 196
# 48
# epoch [81/300], train loss:0.0312
# epoch [81/300], val loss:0.2684
# epoch [81/300], train accuracy:0.9745
# epoch [81/300], val accuracy:0.4792
# 196
# 48
# epoch [82/300], train loss:0.0276
# epoch [82/300], val loss:0.2613
# epoch [82/300], train accuracy:0.9949
# epoch [82/300], val accuracy:0.4792
# 196
# 48
# epoch [83/300], train loss:0.0242
# epoch [83/300], val loss:0.2793
# epoch [83/300], train accuracy:0.9949
# epoch [83/300], val accuracy:0.3542
# 196
# 48
# epoch [84/300], train loss:0.0262
# epoch [84/300], val loss:0.2858
# epoch [84/300], train accuracy:0.9898
# epoch [84/300], val accuracy:0.5208
# 196
# 48
# epoch [85/300], train loss:0.0254
# epoch [85/300], val loss:0.2717
# epoch [85/300], train accuracy:0.9898
# epoch [85/300], val accuracy:0.5000
# 196
# 48
# epoch [86/300], train loss:0.0330
# epoch [86/300], val loss:0.2386
# epoch [86/300], train accuracy:0.9847
# epoch [86/300], val accuracy:0.5625
# 196
# 48
# epoch [87/300], train loss:0.0293
# epoch [87/300], val loss:0.2318
# epoch [87/300], train accuracy:0.9898
# epoch [87/300], val accuracy:0.4792
# 196
# 48
# epoch [88/300], train loss:0.0257
# epoch [88/300], val loss:0.2631
# epoch [88/300], train accuracy:0.9898
# epoch [88/300], val accuracy:0.5000
# 196
# 48
# epoch [89/300], train loss:0.0323
# epoch [89/300], val loss:0.2577
# epoch [89/300], train accuracy:0.9847
# epoch [89/300], val accuracy:0.5625
# 196
# 48
# epoch [90/300], train loss:0.0280
# epoch [90/300], val loss:0.2245
# epoch [90/300], train accuracy:0.9847
# epoch [90/300], val accuracy:0.5000
# 196
# 48
# epoch [91/300], train loss:0.0314
# epoch [91/300], val loss:0.2465
# epoch [91/300], train accuracy:0.9694
# epoch [91/300], val accuracy:0.5000
# 196
# 48
# epoch [92/300], train loss:0.0266
# epoch [92/300], val loss:0.2622
# epoch [92/300], train accuracy:0.9847
# epoch [92/300], val accuracy:0.5417
# 196
# 48
# epoch [93/300], train loss:0.0252
# epoch [93/300], val loss:0.2531
# epoch [93/300], train accuracy:0.9847
# epoch [93/300], val accuracy:0.5000
# 196
# 48
# epoch [94/300], train loss:0.0247
# epoch [94/300], val loss:0.2795
# epoch [94/300], train accuracy:0.9847
# epoch [94/300], val accuracy:0.5208
# 196
# 48
# epoch [95/300], train loss:0.0257
# epoch [95/300], val loss:0.2483
# epoch [95/300], train accuracy:0.9898
# epoch [95/300], val accuracy:0.5417
# 196
# 48
# epoch [96/300], train loss:0.0273
# epoch [96/300], val loss:0.2453
# epoch [96/300], train accuracy:0.9898
# epoch [96/300], val accuracy:0.4792
# 196
# epoch [134/300], train loss:0.0231
# epoch [134/300], val loss:0.2596
# epoch [134/300], train accuracy:0.9949
# epoch [134/300], val accuracy:0.5417
# 196
# 48
# epoch [135/300], train loss:0.0223
# epoch [135/300], val loss:0.2279
# epoch [135/300], train accuracy:0.9847
# epoch [135/300], val accuracy:0.5000
# 196
# 48
# epoch [136/300], train loss:0.0341
# epoch [136/300], val loss:0.2382
# epoch [136/300], train accuracy:0.9745
# epoch [136/300], val accuracy:0.5208
# 196
# 48
# epoch [137/300], train loss:0.0268
# epoch [137/300], val loss:0.2556
# epoch [137/300], train accuracy:0.9847
# epoch [137/300], val accuracy:0.5417
# 196
# 48
# epoch [138/300], train loss:0.0236
# epoch [138/300], val loss:0.2497
# epoch [138/300], train accuracy:0.9898
# epoch [138/300], val accuracy:0.5625
# 196
# 48
# epoch [139/300], train loss:0.0228
# epoch [139/300], val loss:0.2477
# epoch [139/300], train accuracy:0.9847
# epoch [139/300], val accuracy:0.4167
# 196
# 48
# epoch [140/300], train loss:0.0241
# epoch [140/300], val loss:0.2266
# epoch [140/300], train accuracy:0.9898
# epoch [140/300], val accuracy:0.4583
# 196
# 48
# epoch [141/300], train loss:0.0261
# epoch [141/300], val loss:0.2389
# epoch [141/300], train accuracy:0.9898
# epoch [141/300], val accuracy:0.4792
# 196
# 48
# epoch [142/300], train loss:0.0237
# epoch [142/300], val loss:0.2384
# epoch [142/300], train accuracy:0.9847
# epoch [142/300], val accuracy:0.5000
# 196
# 48
# epoch [143/300], train loss:0.0263
# epoch [143/300], val loss:0.2272
# epoch [143/300], train accuracy:0.9847
# epoch [143/300], val accuracy:0.5417
# 196
# 48
# epoch [144/300], train loss:0.0243
# epoch [144/300], val loss:0.2539
# epoch [144/300], train accuracy:0.9949
# epoch [144/300], val accuracy:0.5625
# 196
# 48
# epoch [145/300], train loss:0.0256
# epoch [145/300], val loss:0.2563
# epoch [145/300], train accuracy:0.9796
# epoch [145/300], val accuracy:0.3958
# 196
# 48
# epoch [146/300], train loss:0.0285
# epoch [146/300], val loss:0.2689
# epoch [146/300], train accuracy:0.9847
# epoch [146/300], val accuracy:0.5208
# 196
# 48
# epoch [147/300], train loss:0.0284
# epoch [147/300], val loss:0.2645
# epoch [147/300], train accuracy:0.9898
# epoch [147/300], val accuracy:0.5000
# 196
# 48
# epoch [148/300], train loss:0.0251
# epoch [148/300], val loss:0.2360
# epoch [148/300], train accuracy:0.9847
# epoch [148/300], val accuracy:0.3958
# 196
# 48
# epoch [149/300], train loss:0.0222
# epoch [149/300], val loss:0.2639
# epoch [149/300], train accuracy:0.9898
# epoch [149/300], val accuracy:0.5417
# 196
# 48
# epoch [150/300], train loss:0.0204
# epoch [150/300], val loss:0.2691
# epoch [150/300], train accuracy:0.9898
# epoch [150/300], val accuracy:0.5208
# 196
# 48
# epoch [151/300], train loss:0.0221
# epoch [151/300], val loss:0.2490
# epoch [151/300], train accuracy:0.9898
# epoch [151/300], val accuracy:0.5000
# 196
# 48
# epoch [152/300], train loss:0.0230
# epoch [152/300], val loss:0.2383
# epoch [152/300], train accuracy:0.9949
# epoch [171/300], val loss:0.2361
# epoch [171/300], train accuracy:0.9847
# epoch [171/300], val accuracy:0.5833
# 196
# 48
# epoch [172/300], train loss:0.0222
# epoch [172/300], val loss:0.2389
# epoch [172/300], train accuracy:0.9847
# epoch [172/300], val accuracy:0.4583
# 196
# 48
# epoch [173/300], train loss:0.0232
# epoch [173/300], val loss:0.2311
# epoch [173/300], train accuracy:0.9898
# epoch [173/300], val accuracy:0.5417
# 196
# 48
# epoch [174/300], train loss:0.0227
# epoch [174/300], val loss:0.2254
# epoch [174/300], train accuracy:0.9898
# epoch [174/300], val accuracy:0.5208
# 196
# 48
# epoch [175/300], train loss:0.0192
# epoch [175/300], val loss:0.2123
# epoch [175/300], train accuracy:0.9949
# epoch [175/300], val accuracy:0.5417
# 196
# 48
# epoch [176/300], train loss:0.0238
# epoch [176/300], val loss:0.2204
# epoch [176/300], train accuracy:0.9898
# epoch [176/300], val accuracy:0.5625
# 196
# 48
# epoch [177/300], train loss:0.0219
# epoch [177/300], val loss:0.2453
# epoch [177/300], train accuracy:0.9949
# epoch [177/300], val accuracy:0.5208
# 196
# 48
# epoch [178/300], train loss:0.0217
# epoch [178/300], val loss:0.2435
# epoch [178/300], train accuracy:0.9898
# epoch [178/300], val accuracy:0.5208
# 196
# 48
# epoch [179/300], train loss:0.0212
# epoch [179/300], val loss:0.2521
# epoch [179/300], train accuracy:0.9898
# epoch [179/300], val accuracy:0.4375
# 196
# 48
# epoch [180/300], train loss:0.0229
# epoch [180/300], val loss:0.2394
# epoch [180/300], train accuracy:0.9898
# epoch [180/300], val accuracy:0.5833
# 196
# 48
# epoch [181/300], train loss:0.0252
# epoch [181/300], val loss:0.1799
# epoch [181/300], train accuracy:0.9847
# epoch [181/300], val accuracy:0.6042
# 196
# 48
# epoch [182/300], train loss:0.0314
# epoch [182/300], val loss:0.2443
# epoch [182/300], train accuracy:0.9745
# epoch [182/300], val accuracy:0.4792
# 196
# 48
# epoch [183/300], train loss:0.0239
# epoch [183/300], val loss:0.2472
# epoch [183/300], train accuracy:0.9898
# epoch [183/300], val accuracy:0.5417
# 196
# 48
# epoch [184/300], train loss:0.0251
# epoch [184/300], val loss:0.2191
# epoch [184/300], train accuracy:0.9796
# epoch [184/300], val accuracy:0.5833
# 196
# 48
# epoch [185/300], train loss:0.0279
# epoch [185/300], val loss:0.1948
# epoch [185/300], train accuracy:0.9796
# epoch [185/300], val accuracy:0.5417
# 196
# 48
# epoch [186/300], train loss:0.0251
# epoch [186/300], val loss:0.2171
# epoch [186/300], train accuracy:0.9898
# epoch [186/300], val accuracy:0.5208
# 196
# 48
# epoch [187/300], train loss:0.0215
# epoch [187/300], val loss:0.2151
# epoch [187/300], train accuracy:0.9898
# epoch [187/300], val accuracy:0.4583
# 196
# 48
# epoch [188/300], train loss:0.0209
# epoch [188/300], val loss:0.2305
# epoch [188/300], train accuracy:0.9949
# epoch [188/300], val accuracy:0.5417
# 196
# 48
# epoch [189/300], train loss:0.0203
# epoch [189/300], val loss:0.2425
# epoch [189/300], train accuracy:0.9898
# epoch [189/300], val accuracy:0.4792
# 196
# 48
# epoch [190/300], train loss:0.0246
# epoch [190/300], val loss:0.2160
# epoch [190/300], train accuracy:0.9847
# epoch [190/300], val accuracy:0.5417
# 196
# 48
# epoch [191/300], train loss:0.0228
# epoch [191/300], val loss:0.2175
# epoch [191/300], train accuracy:0.9898
# epoch [191/300], val accuracy:0.6042
# 196
# 48
# epoch [192/300], train loss:0.0237
# epoch [192/300], val loss:0.2293
# epoch [192/300], train accuracy:0.9898
# epoch [192/300], val accuracy:0.5417
# 196
# 48
# epoch [193/300], train loss:0.0242
# epoch [193/300], val loss:0.2377
# epoch [193/300], train accuracy:0.9898
# epoch [193/300], val accuracy:0.5417
# 196
# 48
# epoch [194/300], train loss:0.0283
# epoch [194/300], val loss:0.2314
# epoch [194/300], train accuracy:0.9796
# epoch [194/300], val accuracy:0.4792
# 196
# 48
# epoch [195/300], train loss:0.0240
# epoch [195/300], val loss:0.2269
# epoch [195/300], train accuracy:0.9847
# epoch [195/300], val accuracy:0.5417
# 196
# 48
# epoch [196/300], train loss:0.0211
# epoch [196/300], val loss:0.2386
# epoch [196/300], train accuracy:0.9949
# epoch [196/300], val accuracy:0.4792
# 196
# 48
# epoch [197/300], train loss:0.0193
# epoch [197/300], val loss:0.2523
# epoch [197/300], train accuracy:0.9949
# epoch [197/300], val accuracy:0.5625
# 196
# 48
# epoch [198/300], train loss:0.0203
# epoch [198/300], val loss:0.2397
# epoch [198/300], train accuracy:0.9949
# epoch [198/300], val accuracy:0.4792
# 196
# 48
# epoch [199/300], train loss:0.0241
# epoch [199/300], val loss:0.2251
# epoch [199/300], train accuracy:0.9898
# epoch [199/300], val accuracy:0.4167
# 196
# 48
# epoch [200/300], train loss:0.0268
# epoch [200/300], val loss:0.2376
# epoch [200/300], train accuracy:0.9796
# epoch [200/300], val accuracy:0.5417
# 196
# 48
# epoch [201/300], train loss:0.0235
# epoch [201/300], val loss:0.2323
# epoch [201/300], train accuracy:0.9898
# epoch [201/300], val accuracy:0.5000
# 196
# 48
# epoch [202/300], train loss:0.0232
# epoch [202/300], val loss:0.2352
# epoch [202/300], train accuracy:0.9949
# epoch [202/300], val accuracy:0.5417
# 196
# 48
# epoch [203/300], train loss:0.0238
# epoch [203/300], val loss:0.2380
# epoch [203/300], train accuracy:0.9847
# epoch [203/300], val accuracy:0.4792
# 196
# 48
# epoch [204/300], train loss:0.0289
# epoch [204/300], val loss:0.2338
# epoch [204/300], train accuracy:0.9847
# epoch [204/300], val accuracy:0.5417
# 196
# 48
# epoch [205/300], train loss:0.0207
# epoch [205/300], val loss:0.2422
# epoch [205/300], train accuracy:0.9949
# epoch [205/300], val accuracy:0.4792
# 196
# 48
# epoch [206/300], train loss:0.0209
# epoch [206/300], val loss:0.2099
# epoch [206/300], train accuracy:0.9796
# epoch [206/300], val accuracy:0.6042
# 196
# 48
# epoch [207/300], train loss:0.0239
# epoch [207/300], val loss:0.2382
# epoch [207/300], train accuracy:0.9898
# epoch [207/300], val accuracy:0.4792
# 196
# 48
# epoch [208/300], train loss:0.0207
# epoch [226/300], val accuracy:0.4792
# 196
# 48
# epoch [227/300], train loss:0.0192
# epoch [227/300], val loss:0.2193
# epoch [227/300], train accuracy:0.9898
# epoch [227/300], val accuracy:0.5625
# 196
# 48
# epoch [228/300], train loss:0.0196
# epoch [228/300], val loss:0.2295
# epoch [228/300], train accuracy:0.9898
# epoch [228/300], val accuracy:0.5833
# 196
# 48
# epoch [229/300], train loss:0.0245
# epoch [229/300], val loss:0.2285
# epoch [229/300], train accuracy:0.9847
# epoch [229/300], val accuracy:0.5000
# 196
# 48
# epoch [230/300], train loss:0.0318
# epoch [230/300], val loss:0.2128
# epoch [230/300], train accuracy:0.9643
# epoch [230/300], val accuracy:0.6875
# 196
# 48
# epoch [231/300], train loss:0.0312
# epoch [231/300], val loss:0.2266
# epoch [231/300], train accuracy:0.9643
# epoch [231/300], val accuracy:0.6042
# 196
# 48
# epoch [232/300], train loss:0.0358
# epoch [232/300], val loss:0.2319
# epoch [232/300], train accuracy:0.9745
# epoch [232/300], val accuracy:0.4792
# 196
# 48
# epoch [233/300], train loss:0.0235
# epoch [233/300], val loss:0.2350
# epoch [233/300], train accuracy:0.9898
# epoch [233/300], val accuracy:0.6042
# 196
# 48
# epoch [234/300], train loss:0.0189
# epoch [234/300], val loss:0.2301
# epoch [234/300], train accuracy:0.9949
# epoch [234/300], val accuracy:0.5000
# 196
# 48
# epoch [235/300], train loss:0.0215
# epoch [235/300], val loss:0.2131
# epoch [235/300], train accuracy:0.9898
# epoch [235/300], val accuracy:0.6042
# 196
# 48
# epoch [236/300], train loss:0.0196
# epoch [236/300], val loss:0.2193
# epoch [236/300], train accuracy:0.9898
# epoch [236/300], val accuracy:0.5625
# 196
# 48
# epoch [237/300], train loss:0.0199
# epoch [237/300], val loss:0.2516
# epoch [237/300], train accuracy:0.9949
# epoch [237/300], val accuracy:0.6042
# 196
# 48
# epoch [238/300], train loss:0.0264
# epoch [238/300], val loss:0.1949
# epoch [238/300], train accuracy:0.9796
# epoch [238/300], val accuracy:0.5417
# 196
# 48
# epoch [239/300], train loss:0.0228
# epoch [239/300], val loss:0.2516
# epoch [239/300], train accuracy:0.9898
# epoch [239/300], val accuracy:0.6042
# 196
# 48
# epoch [240/300], train loss:0.0190
# epoch [240/300], val loss:0.2257
# epoch [240/300], train accuracy:0.9898
# epoch [240/300], val accuracy:0.6250
# 196
# 48
# epoch [241/300], train loss:0.0228
# epoch [241/300], val loss:0.2144
# epoch [241/300], train accuracy:0.9847
# epoch [241/300], val accuracy:0.5625
# 196
# 48
# epoch [242/300], train loss:0.0232
# epoch [242/300], val loss:0.2222
# epoch [242/300], train accuracy:0.9898
# epoch [242/300], val accuracy:0.6042
# 196
# 48
# epoch [243/300], train loss:0.0255
# epoch [243/300], val loss:0.2047
# epoch [243/300], train accuracy:0.9847
# epoch [243/300], val accuracy:0.5417
# 196
# 48
# epoch [244/300], train loss:0.0258
# epoch [244/300], val loss:0.2677
# epoch [244/300], train accuracy:0.9796
# epoch [244/300], val accuracy:0.5417
# 196
# 48
# epoch [245/300], train loss:0.0224
# epoch [245/300], val loss:0.2184
# epoch [245/300], train accuracy:0.9847
# epoch [245/300], val accuracy:0.5625
# 196
# 48
# epoch [246/300], train loss:0.0254
# epoch [246/300], val loss:0.2486
# epoch [246/300], train accuracy:0.9847
# epoch [246/300], val accuracy:0.4792
# 196
# 48
# epoch [247/300], train loss:0.0185
# epoch [247/300], val loss:0.2548
# epoch [247/300], train accuracy:0.9949
# epoch [247/300], val accuracy:0.5833
# 196
# 48
# epoch [248/300], train loss:0.0190
# epoch [248/300], val loss:0.2498
# epoch [248/300], train accuracy:0.9898
# epoch [248/300], val accuracy:0.5417
# 196
# 48
# epoch [249/300], train loss:0.0233
# epoch [249/300], val loss:0.2793
# epoch [249/300], train accuracy:0.9847
# epoch [249/300], val accuracy:0.4792
# 196
# 48
# epoch [250/300], train loss:0.0217
# epoch [250/300], val loss:0.2576
# epoch [250/300], train accuracy:0.9898
# epoch [250/300], val accuracy:0.3542
# 196
# 48
# epoch [251/300], train loss:0.0215
# epoch [251/300], val loss:0.2346
# epoch [251/300], train accuracy:0.9949
# epoch [251/300], val accuracy:0.6667
# 196
# 48
# epoch [252/300], train loss:0.0208
# epoch [252/300], val loss:0.2575
# epoch [252/300], train accuracy:0.9898
# epoch [252/300], val accuracy:0.4375
# 196
# 48
# epoch [253/300], train loss:0.0285
# epoch [253/300], val loss:0.2465
# epoch [253/300], train accuracy:0.9796
# epoch [253/300], val accuracy:0.5208
# 196
# 48
# epoch [254/300], train loss:0.0309
# epoch [254/300], val loss:0.2596
# epoch [254/300], train accuracy:0.9745
# epoch [254/300], val accuracy:0.5417
# 196
# 48
# epoch [255/300], train loss:0.0264
# epoch [255/300], val loss:0.2412
# epoch [255/300], train accuracy:0.9847
# epoch [255/300], val accuracy:0.5417
# 196
# 48
# epoch [256/300], train loss:0.0248
# epoch [256/300], val loss:0.2533
# epoch [256/300], train accuracy:0.9847
# epoch [256/300], val accuracy:0.4583
# 196
# 48
# epoch [257/300], train loss:0.0248
# epoch [257/300], val loss:0.2128
# epoch [257/300], train accuracy:0.9847
# epoch [257/300], val accuracy:0.6667
# 196
# 48
# epoch [258/300], train loss:0.0284
# epoch [258/300], val loss:0.2425
# epoch [258/300], train accuracy:0.9898
# epoch [258/300], val accuracy:0.5000
# 196
# 48
# epoch [259/300], train loss:0.0255
# epoch [259/300], val loss:0.2211
# epoch [259/300], train accuracy:0.9898
# epoch [259/300], val accuracy:0.5000
# 196
# 48
# epoch [260/300], train loss:0.0227
# epoch [260/300], val loss:0.2496
# epoch [260/300], train accuracy:0.9847
# epoch [260/300], val accuracy:0.6042
# 196
# 48
# epoch [261/300], train loss:0.0202
# epoch [261/300], val loss:0.2373
# epoch [261/300], train accuracy:0.9898
# epoch [261/300], val accuracy:0.5000
# 196
# 48
# epoch [262/300], train loss:0.0190
# epoch [262/300], val loss:0.2407
# epoch [262/300], train accuracy:0.9949
# epoch [262/300], val accuracy:0.6042
# 196
# 48
# epoch [263/300], train loss:0.0197
# epoch [263/300], val loss:0.2498
# epoch [263/300], train accuracy:0.9898
# epoch [263/300], val accuracy:0.5417
# 196
# 48
# epoch [264/300], train loss:0.0196
# epoch [264/300], val loss:0.2461
# epoch [264/300], train accuracy:0.9898
# epoch [264/300], val accuracy:0.4792
# 196
# 48
# epoch [265/300], train loss:0.0252
# epoch [265/300], val loss:0.2324
# epoch [265/300], train accuracy:0.9796
# epoch [265/300], val accuracy:0.5417
# 196
# 48
# epoch [266/300], train loss:0.0291
# epoch [266/300], val loss:0.2470
# epoch [266/300], train accuracy:0.9898
# epoch [266/300], val accuracy:0.5000
# 196
# 48
# epoch [267/300], train loss:0.0237
# epoch [267/300], val loss:0.2830
# epoch [267/300], train accuracy:0.9898
# epoch [267/300], val accuracy:0.4792
# 196
# 48
# epoch [268/300], train loss:0.0213
# epoch [268/300], val loss:0.2610
# epoch [268/300], train accuracy:0.9847
# epoch [268/300], val accuracy:0.4792
# 196
# 48
# epoch [269/300], train loss:0.0207
# epoch [269/300], val loss:0.2331
# epoch [269/300], train accuracy:0.9898
# epoch [269/300], val accuracy:0.6250
# 196
# 48
# epoch [270/300], train loss:0.0208
# epoch [270/300], val loss:0.2441
# epoch [270/300], train accuracy:0.9898
# epoch [270/300], val accuracy:0.5000
# 196
# 48
# epoch [271/300], train loss:0.0189
# epoch [271/300], val loss:0.2663
# epoch [271/300], train accuracy:0.9898
# epoch [271/300], val accuracy:0.5000
# 196
# 48
# epoch [272/300], train loss:0.0237
# epoch [272/300], val loss:0.2414
# epoch [272/300], train accuracy:0.9847
# epoch [272/300], val accuracy:0.4792
# 196
# 48
# epoch [273/300], train loss:0.0232
# epoch [273/300], val loss:0.2476
# epoch [273/300], train accuracy:0.9898
# epoch [273/300], val accuracy:0.6250
# 196
# 48
# epoch [274/300], train loss:0.0236
# epoch [274/300], val loss:0.2402
# epoch [274/300], train accuracy:0.9898
# epoch [274/300], val accuracy:0.4792
# 196
# 48
# epoch [275/300], train loss:0.0202
# epoch [275/300], val loss:0.2301
# epoch [275/300], train accuracy:0.9898
# epoch [275/300], val accuracy:0.4792
# 196
# 48
# epoch [276/300], train loss:0.0256
# epoch [276/300], val loss:0.2246
# epoch [276/300], train accuracy:0.9847
# epoch [276/300], val accuracy:0.5000
# 196
# 48
# epoch [277/300], train loss:0.0204
# epoch [277/300], val loss:0.2513
# epoch [277/300], train accuracy:0.9949
# epoch [277/300], val accuracy:0.5208
# 196
# 48
# epoch [278/300], train loss:0.0221
# epoch [278/300], val loss:0.2338
# epoch [278/300], train accuracy:0.9847
# epoch [278/300], val accuracy:0.6250
# 196
# 48
# epoch [279/300], train loss:0.0260
# epoch [279/300], val loss:0.2532
# epoch [279/300], train accuracy:0.9745
# epoch [279/300], val accuracy:0.5417
# 196
# 48
# epoch [280/300], train loss:0.0289
# epoch [280/300], val loss:0.2160
# epoch [280/300], train accuracy:0.9847
# epoch [280/300], val accuracy:0.5208
# 196
# 48
# epoch [281/300], train loss:0.0275
# epoch [281/300], val loss:0.2218
# epoch [281/300], train accuracy:0.9898
# epoch [281/300], val accuracy:0.4583
# 196
# 48
# epoch [282/300], train loss:0.0239
# epoch [282/300], val loss:0.2373
# epoch [282/300], train accuracy:0.9898
# epoch [282/300], val accuracy:0.4583
# 196
# 48
# epoch [283/300], train loss:0.0178
# epoch [283/300], val loss:0.2538
# epoch [283/300], train accuracy:0.9898
# epoch [283/300], val accuracy:0.5417
# 196
# 48
# epoch [284/300], train loss:0.0231
# epoch [284/300], val loss:0.2390
# epoch [284/300], train accuracy:0.9898
# epoch [284/300], val accuracy:0.5417
# 196
# 48
# epoch [285/300], train loss:0.0260
# epoch [285/300], val loss:0.2431
# epoch [285/300], train accuracy:0.9796
# epoch [285/300], val accuracy:0.5417
# 196
# 48
# epoch [286/300], train loss:0.0212
# epoch [286/300], val loss:0.2456
# epoch [286/300], train accuracy:0.9847
# epoch [286/300], val accuracy:0.4792
# 196
# 48
# epoch [287/300], train loss:0.0183
# epoch [287/300], val loss:0.2561
# epoch [287/300], train accuracy:0.9898
# epoch [287/300], val accuracy:0.5000
# 196
# 48
# epoch [288/300], train loss:0.0216
# epoch [288/300], val loss:0.2479
# epoch [288/300], train accuracy:0.9898
# epoch [288/300], val accuracy:0.5417
# 196
# 48
# epoch [289/300], train loss:0.0233
# epoch [289/300], val loss:0.2286
# epoch [289/300], train accuracy:0.9847
# epoch [289/300], val accuracy:0.4583
# 196
# 48
# epoch [290/300], train loss:0.0216
# epoch [290/300], val loss:0.2668
# epoch [290/300], train accuracy:0.9898
# epoch [290/300], val accuracy:0.4792
# 196
# 48
# epoch [291/300], train loss:0.0224
# epoch [291/300], val loss:0.2486
# epoch [291/300], train accuracy:0.9949
# epoch [291/300], val accuracy:0.5417
# 196
# 48
# epoch [292/300], train loss:0.0190
# epoch [292/300], val loss:0.2755
# epoch [292/300], train accuracy:0.9898
# epoch [292/300], val accuracy:0.6042
# 196
# 48
# epoch [293/300], train loss:0.0227
# epoch [293/300], val loss:0.2452
# epoch [293/300], train accuracy:0.9898
# epoch [293/300], val accuracy:0.5000
# 196
# 48
# epoch [294/300], train loss:0.0232
# epoch [294/300], val loss:0.2526
# epoch [294/300], train accuracy:0.9898
# epoch [294/300], val accuracy:0.5417
# 196
# 48
# epoch [295/300], train loss:0.0257
# epoch [295/300], val loss:0.2442
# epoch [295/300], train accuracy:0.9745
# epoch [295/300], val accuracy:0.5000
# 196
# 48
# epoch [296/300], train loss:0.0339
# epoch [296/300], val loss:0.2599
# epoch [296/300], train accuracy:0.9796
# epoch [296/300], val accuracy:0.5417
# 196
# 48
# epoch [297/300], train loss:0.0240
# epoch [297/300], val loss:0.2388
# epoch [297/300], train accuracy:0.9898
# epoch [297/300], val accuracy:0.4792
# 196
# 48
# epoch [298/300], train loss:0.0261
# epoch [298/300], val loss:0.2663
# epoch [298/300], train accuracy:0.9796
# epoch [298/300], val accuracy:0.5417
# 196
# 48
# epoch [299/300], train loss:0.0247
# epoch [299/300], val loss:0.2646
# epoch [299/300], train accuracy:0.9898
# epoch [299/300], val accuracy:0.5000
# 196
# 48
# epoch [300/300], train loss:0.0222
# epoch [300/300], val loss:0.2743
# epoch [300/300], train accuracy:0.9847
# epoch [300/300], val accuracy:0.4792
